# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import seaborn as sns
import re
import nltk
import random

from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.preprocessing import StandardScaler

plt.style.use('ggplot')

nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /Users/olive/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
SEED = 7

np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# ## Load Data

# %%
DATA_PATH = '/Users/olive/github/fantasynba/data/projections.xlsx'

nba = pd.read_excel(DATA_PATH)

nba[:10]
# Out:
#    R#                                             PLAYER    POS TEAM  GP  \
# 0   1  James Harden The departure Of Capela has resul...  PG,SG  HOU  78
# 1   2  Anthony Davis Has been battling injuries for m...   PF,C  LAL  74
# 2   3  Nikola Jokic The buy-low window has well and t...   PF,C  DEN  76
# 3   4  Damian Lillard Portland's playoff chances ride...     PG  POR  68
# 4   5  Kawhi Leonard A top 10 fantasy player in re-dr...  SG,SF  LAC  68
# 5   6  John Collins Sure, his rebounds and blocks tak...   PF,C  ATL  46
# 6   7  Jayson Tatum His FG% is trending in the right ...  SF,PF  BOS  78
# 7   8  Russell Westbrook Westbrook is back, and his s...     PG  HOU  76
# 8   9  Bradley Beal He's going to continue playing 35...     SG  WAS  78
# 9  10  Karl-Anthony Towns Minnesota finally managed t...      C  MIN  45
#
#     MPG               FG%              FT%  3PM   PTS  TREB  AST  STL  BLK  \
# 0  36.0   0.45 (9.6/21.4)  0.88 (8.9/10.1)  4.8  32.9   5.8  7.2  2.0  0.8
# 1  34.0   0.54 (9.4/17.6)   0.84 (6.5/7.8)  1.0  26.4  10.0  3.7  1.5  2.6
# 2  33.0   0.55 (9.2/16.7)   0.82 (3.7/4.5)  1.1  23.1  10.4  7.5  1.3  1.0
# 3  33.0   0.45 (9.2/20.1)   0.90 (6.9/7.6)  4.0  29.2   3.9  7.7  1.0  0.4
# 4  30.0   0.47 (9.4/20.2)   0.90 (5.7/6.3)  2.3  26.8   6.8  5.1  1.7  0.8
# 5  32.0  0.58 (10.1/17.4)   0.82 (2.2/2.7)  1.7  24.2  10.0  2.0  0.7  1.5
# 6  36.0  0.47 (10.2/21.7)   0.83 (2.9/3.5)  3.6  27.0   7.9  3.8  1.4  1.1
# 7  36.0  0.50 (12.2/24.3)   0.79 (5.6/7.1)  0.7  30.7   8.7  6.5  2.0  0.4
# 8  36.0  0.46 (11.9/25.8)   0.86 (5.5/6.5)  3.6  32.8   4.0  6.2  1.5  0.4
# 9  30.0   0.51 (8.4/16.3)   0.80 (4.4/5.5)  3.0  24.3   9.6  3.5  0.8  1.3
#
#     TO  TOTAL
# 0  4.3  15.80
# 1  2.1  14.75
# 2  3.3  11.08
# 3  2.9  10.96
# 4  2.3  10.84
# 5  1.8  10.11
# 6  2.3   9.84
# 7  4.4   9.71
# 8  4.4   9.48
# 9  2.8   9.24

# %% [markdown]
# ## Data preprocessing

# %%
nba.drop('TOTAL', axis=1, inplace=True)
nba.drop('R#', axis=1, inplace=True)
nba.drop('GP', axis=1, inplace=True)
nba.drop('TEAM', axis=1, inplace=True)
#nba.drop('POS', axis=1, inplace=True)

# %%
nba.isnull().any().any()
# Out:
# False

# %%
words = set(nltk.corpus.words.words('en'))

def is_name(name):
    player_name = name.split()[:2]
    return ' '.join(player_name)
    
def remove_text_inside_brackets(text, brackets="()"):
    count = [0] * (len(brackets) // 2)
    saved_chars = []
    for character in text:
        for i, b in enumerate(brackets):
            if character == b: 
                kind, is_close = divmod(i, 2)
                count[kind] += (-1)**is_close 
                if count[kind] < 0: 
                    count[kind] = 0  
                else: 
                    break
        else:
            if not any(count):
                saved_chars.append(character)
    return float(''.join(saved_chars))

# %%
nba['PLAYER'] = nba['PLAYER'].apply(is_name)

nba['FG%'] = nba['FG%'].apply(remove_text_inside_brackets)
nba['FT%'] = nba['FT%'].apply(remove_text_inside_brackets)

nba.head()
# Out:
#            PLAYER    POS   MPG   FG%   FT%  3PM   PTS  TREB  AST  STL  BLK  \
# 0    James Harden  PG,SG  36.0  0.45  0.88  4.8  32.9   5.8  7.2  2.0  0.8
# 1   Anthony Davis   PF,C  34.0  0.54  0.84  1.0  26.4  10.0  3.7  1.5  2.6
# 2    Nikola Jokic   PF,C  33.0  0.55  0.82  1.1  23.1  10.4  7.5  1.3  1.0
# 3  Damian Lillard     PG  33.0  0.45  0.90  4.0  29.2   3.9  7.7  1.0  0.4
# 4   Kawhi Leonard  SG,SF  30.0  0.47  0.90  2.3  26.8   6.8  5.1  1.7  0.8
#
#     TO
# 0  4.3
# 1  2.1
# 2  3.3
# 3  2.9
# 4  2.3

# %%
nba.shape
# Out:
# (200, 12)

# %%
nba.mean()
# Out:
# MPG     28.4950
# FG%      0.4755
# FT%      0.7829
# 3PM      1.5490
# PTS     15.1525
# TREB     5.7515
# AST      3.2190
# STL      0.9705
# BLK      0.6780
# TO       1.8180
# dtype: float64

# %% [markdown]
# # EDA

# %%
#sns.pairplot(nba[["MPG", "FG%", "FT%", "3PM", "PTS", "AST", "STL", "BLK", "TO"]])

# %%
correlation = nba[["FG%", "FT%", "3PM", "PTS", "AST", "STL", "BLK", "TO"]].corr()
sns.heatmap(correlation, annot=True)

# %% [markdown]
# # KMeans Clustering

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
X = nba._get_numeric_data().dropna(axis=1)
X_scaled = scaler.fit_transform(X)

pca_2 = PCA(2)
pca_2.fit(X_scaled)
X_pca = pca_2.transform(X_scaled)

distortions = []

for i in range(1, 10):
    km = KMeans(
        n_clusters=i, 
        init='random', 
        n_init=10, 
        max_iter=300, 
        tol=1e-04, 
        random_state=0)
    km.fit(X_pca)
    distortions.append(km.inertia_)
    
plt.plot(range(1, 10), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
# Out:
# Text(0, 0.5, 'Distortion')

# %%
kmeans_model = KMeans(n_clusters=9, 
                      init='random',
                      n_init=10,
                      max_iter=300,
                      tol=1e-04,
                      random_state=0)
kmeans_model.fit(X_pca)
labels = kmeans_model.labels_

centers = kmeans_model.cluster_centers_
plt.scatter(x = X_pca[:,0], y = X_pca[:,1], c = labels)
plt.scatter(x = centers[:, 0], y = centers[:, 1], c = 'black', s = 200, alpha = 0.5)

# %%
nba['Cluster'] = kmeans_model.labels_
nba[:12]
# Out:
#                 PLAYER       POS   MPG   FG%   FT%  3PM   PTS  TREB   AST  \
# 0         James Harden     PG,SG  36.0  0.45  0.88  4.8  32.9   5.8   7.2
# 1        Anthony Davis      PF,C  34.0  0.54  0.84  1.0  26.4  10.0   3.7
# 2         Nikola Jokic      PF,C  33.0  0.55  0.82  1.1  23.1  10.4   7.5
# 3       Damian Lillard        PG  33.0  0.45  0.90  4.0  29.2   3.9   7.7
# 4        Kawhi Leonard     SG,SF  30.0  0.47  0.90  2.3  26.8   6.8   5.1
# 5         John Collins      PF,C  32.0  0.58  0.82  1.7  24.2  10.0   2.0
# 6         Jayson Tatum     SF,PF  36.0  0.47  0.83  3.6  27.0   7.9   3.8
# 7    Russell Westbrook        PG  36.0  0.50  0.79  0.7  30.7   8.7   6.5
# 8         Bradley Beal        SG  36.0  0.46  0.86  3.6  32.8   4.0   6.2
# 9   Karl-Anthony Towns         C  30.0  0.51  0.80  3.0  24.3   9.6   3.5
# 10          Trae Young        PG  35.0  0.43  0.86  3.7  29.9   4.0   9.8
# 11        LeBron James  PG,SF,PF  34.0  0.51  0.71  2.6  26.2   7.5  10.6
#
#     STL  BLK   TO  Cluster
# 0   2.0  0.8  4.3        2
# 1   1.5  2.6  2.1        3
# 2   1.3  1.0  3.3        3
# 3   1.0  0.4  2.9        2
# 4   1.7  0.8  2.3        2
# 5   0.7  1.5  1.8        3
# 6   1.4  1.1  2.3        2
# 7   2.0  0.4  4.4        2
# 8   1.5  0.4  4.4        2
# 9   0.8  1.3  2.8        6
# 10  1.0  0.2  4.4        2
# 11  1.1  0.6  4.7        2

# %%
nba.mean()
# Out:
# MPG        28.4950
# FG%         0.4755
# FT%         0.7829
# 3PM         1.5490
# PTS        15.1525
# TREB        5.7515
# AST         3.2190
# STL         0.9705
# BLK         0.6780
# TO          1.8180
# Cluster     4.2750
# dtype: float64

# %%
def get_cluster(val):
    return nba.loc[nba['Cluster'] == val]

print(get_cluster(2))
# print(get_cluster(3).mean())
# Out:
#                PLAYER   MPG   FG%   FT%  3PM   PTS  TREB   AST  STL  BLK   TO  \
# 0        James Harden  36.0  0.45  0.88  4.8  32.9   5.8   7.2  2.0  0.8  4.3
# 3      Damian Lillard  33.0  0.45  0.90  4.0  29.2   3.9   7.7  1.0  0.4  2.9
# 4       Kawhi Leonard  30.0  0.47  0.90  2.3  26.8   6.8   5.1  1.7  0.8  2.3
# 6        Jayson Tatum  36.0  0.47  0.83  3.6  27.0   7.9   3.8  1.4  1.1  2.3
# 7   Russell Westbrook  36.0  0.50  0.79  0.7  30.7   8.7   6.5  2.0  0.4  4.4
# 8        Bradley Beal  36.0  0.46  0.86  3.6  32.8   4.0   6.2  1.5  0.4  4.4
# 10         Trae Young  35.0  0.43  0.86  3.7  29.9   4.0   9.8  1.0  0.2  4.4
# 11       LeBron James  34.0  0.51  0.71  2.6  26.2   7.5  10.6  1.1  0.6  4.7
# 18       Jrue Holiday  34.0  0.46  0.78  1.8  18.6   4.6   7.7  1.7  1.2  2.7
# 19        Luka Doncic  32.0  0.44  0.77  2.3  27.4   9.2   8.6  1.1  0.3  3.7
# 23       Devin Booker  35.0  0.43  0.91  2.2  24.6   4.0   6.2  0.9  0.2  3.7
# 25         Kyle Lowry  33.0  0.41  0.85  2.9  19.6   5.1   8.1  1.3  0.5  3.0
# 26         Lonzo Ball  32.0  0.46  0.61  2.4  14.0   7.5   8.8  1.7  0.6  3.4
# 29        Zach LaVine  35.0  0.47  0.79  3.0  26.5   4.9   4.4  1.5  0.4  3.5
# 32   Donovan Mitchell  34.0  0.47  0.87  2.6  24.9   4.6   4.2  1.1  0.3  3.4
# 49       De'Aaron Fox  33.0  0.47  0.73  1.3  20.4   4.3   6.9  1.4  0.8  3.4
#
#     Cluster
# 0         2
# 3         2
# 4         2
# 6         2
# 7         2
# 8         2
# 10        2
# 11        2
# 18        2
# 19        2
# 23        2
# 25        2
# 26        2
# 29        2
# 32        2
# 49        2

# %% [markdown]
# ## Organize players into clusters

# %%
#nba.drop('POS', axis=1, inplace=True)

# Top similar players to a specified player
def top_similar_players_in_cluster(search, cluster_category, recommender_df, max_range):
    for player in cluster_category.loc[cluster_category['PLAYER'].str.contains(search), 'PLAYER']:
        return recommender_df[player].sort_values()[0:max_range]
        
def create_recommender(cluster):
    recommender = pairwise_distances(cluster, metric='cosine')
    recommender_df = pd.DataFrame(
        recommender,
        index = cluster.index,
        columns = cluster.index)
    return recommender_df

def show_data_for_similar_players(cluster, players = []):
    return get_cluster(cluster).loc[lambda df: df.PLAYER.isin(players)]

def visualize_data_for_similar_players(player, categories, plt_type):
    colors = plt.rcParams['axes.prop_cycle']()
    
    fig, axes = plt.subplots(3,2, figsize=(12,12), dpi=80)
    
    for ax, cat in zip(axes.flatten(), categories):
        c = next(colors)['color']
        
        if plt_type is 'vlines':
            ax.vlines(x=player['PLAYER'], ymin=0, ymax=player[cat], color=c, alpha=0.7, linewidth=2)
            ax.scatter(x=player['PLAYER'], y=player[cat], color=c, alpha=0.7)
        elif plt_type is 'bar':
            ax.bar(player['PLAYER'], player[cat], color=c, width=.5)
            for i, val in enumerate(player[cat].values):
                ax.text(i, val, float(val), 
                         horizontalalignment='center', 
                         verticalalignment='bottom', 
                         fontdict={'fontweight':500, 'size':12})
        
        ax.title.set_text(cat)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Centers

# %%
db = nba.loc[nba['Cluster'] == 0]

DEFENSIVE_BIGS = db.set_index(['PLAYER'])

# %%
db_recommender = create_recommender(DEFENSIVE_BIGS)
db_recommender.head()
# Out:
# PLAYER             Hassan Whiteside  Mitchell Robinson  Rudy Gobert  \
# PLAYER
# Hassan Whiteside           0.000000           0.012466     0.004629
# Mitchell Robinson          0.012466           0.000000     0.004387
# Rudy Gobert                0.004629           0.004387     0.000000
# Jonas Valanciunas          0.001874           0.009872     0.002118
# Steven Adams               0.016870           0.004526     0.004291
#
# PLAYER             Jonas Valanciunas  Steven Adams  Clint Capela  \
# PLAYER
# Hassan Whiteside        1.873713e-03      0.016870      0.004611
# Mitchell Robinson       9.872494e-03      0.004526      0.003282
# Rudy Gobert             2.117534e-03      0.004291      0.001302
# Jonas Valanciunas       4.440892e-16      0.011437      0.002200
# Steven Adams            1.143662e-02      0.000000      0.007177
#
# PLAYER             DeAndre Jordan  Jarrett Allen
# PLAYER
# Hassan Whiteside         0.007165       0.010191
# Mitchell Robinson        0.012229       0.002879
# Rudy Gobert              0.003091       0.001197
# Jonas Valanciunas        0.005384       0.005947
# Steven Adams             0.006695       0.001312

# %%
GOBERT = top_similar_players_in_cluster(
    search='Rudy Gobert', 
    cluster_category=db,
    recommender_df=db_recommender_df,
    max_range=5
)

# %%
GOBERT_SIMILAR = show_data_for_similar_players(
    cluster = 0,
    players = GOBERT.index.values
)

# %%
visualize_data_for_similar_players(
    player = GOBERT_SIMILAR, 
    categories = ['FG%', 'FT%', '3PM', 'PTS', 'TREB', 'AST'],
    plt_type='bar'
)

# %% [markdown]
# ## All around threats

# %%
at = nba.loc[nba['Cluster'] == 2]

ALL_AROUND_THREATS = at.set_index(['PLAYER'])

# %%
at_recommender = create_recommender(ALL_AROUND_THREATS)
at_recommender.head()
# Out:
# PLAYER             James Harden  Damian Lillard  Kawhi Leonard  Jayson Tatum  \
# PLAYER
# James Harden           0.000000        0.001368   2.767538e-03  8.759106e-03
# Damian Lillard         0.001368        0.000000   4.991633e-03  1.088390e-02
# Kawhi Leonard          0.002768        0.004992   2.220446e-16  4.698214e-03
# Jayson Tatum           0.008759        0.010884   4.698214e-03  1.110223e-16
# Russell Westbrook      0.005923        0.008357   1.951815e-03  6.205292e-03
#
# PLAYER             Russell Westbrook  Bradley Beal  Trae Young  LeBron James  \
# PLAYER
# James Harden                0.005923      0.001178    0.003412      0.009933
# Damian Lillard              0.008357      0.001639    0.001278      0.008957
# Kawhi Leonard               0.001952      0.004452    0.008148      0.010232
# Jayson Tatum                0.006205      0.010277    0.014496      0.013741
# Russell Westbrook           0.000000      0.007130    0.009292      0.007710
#
# PLAYER             Jrue Holiday  Luka Doncic  Devin Booker  Kyle Lowry  \
# PLAYER
# James Harden           0.029767     0.007365      0.009382    0.021819
# Damian Lillard         0.025591     0.008924      0.007323    0.018343
# Kawhi Leonard          0.028302     0.004512      0.010065    0.021730
# Jayson Tatum           0.018110     0.010224      0.006639    0.014175
# Russell Westbrook      0.024506     0.003330      0.008881    0.019121
#
# PLAYER             Lonzo Ball  Zach LaVine  Donovan Mitchell  De'Aaron Fox
# PLAYER
# James Harden         0.057990     0.005648          0.007536      0.018974
# Damian Lillard       0.054734     0.006062          0.007454      0.015952
# Kawhi Leonard        0.053929     0.005414          0.006992      0.018088
# Jayson Tatum         0.038590     0.002641          0.003002      0.011645
# Russell Westbrook    0.046490     0.006136          0.007103      0.014509

# %%
HOLIDAY = top_similar_players_in_cluster(
    search='Jrue Holiday',
    cluster_category=at,
    recommender_df=at_recommender,
    max_range=5
)

LAVINE = top_similar_players_in_cluster(
    search='Zach LaVine',
    cluster_category=at,
    recommender_df=at_recommender,
    max_range=5
)

DONCIC = top_similar_players_in_cluster(
    search = 'Luka Doncic',
    cluster_category=at,
    recommender_df=at_recommender,
    max_range=5
)

# %%
show_data_for_similar_players(
    cluster=2,
    players = HOLIDAY.index.values
)
# Out:
#           PLAYER   MPG   FG%   FT%  3PM   PTS  TREB  AST  STL  BLK   TO  \
# 18  Jrue Holiday  34.0  0.46  0.78  1.8  18.6   4.6  7.7  1.7  1.2  2.7
# 23  Devin Booker  35.0  0.43  0.91  2.2  24.6   4.0  6.2  0.9  0.2  3.7
# 25    Kyle Lowry  33.0  0.41  0.85  2.9  19.6   5.1  8.1  1.3  0.5  3.0
# 26    Lonzo Ball  32.0  0.46  0.61  2.4  14.0   7.5  8.8  1.7  0.6  3.4
# 49  De'Aaron Fox  33.0  0.47  0.73  1.3  20.4   4.3  6.9  1.4  0.8  3.4
#
#     Cluster
# 18        2
# 23        2
# 25        2
# 26        2
# 49        2

# %%
show_data_for_similar_players(
    cluster = 2,
    players = LAVINE.index.values
)
# Out:
#               PLAYER   MPG   FG%   FT%  3PM   PTS  TREB  AST  STL  BLK   TO  \
# 6       Jayson Tatum  36.0  0.47  0.83  3.6  27.0   7.9  3.8  1.4  1.1  2.3
# 8       Bradley Beal  36.0  0.46  0.86  3.6  32.8   4.0  6.2  1.5  0.4  4.4
# 23      Devin Booker  35.0  0.43  0.91  2.2  24.6   4.0  6.2  0.9  0.2  3.7
# 29       Zach LaVine  35.0  0.47  0.79  3.0  26.5   4.9  4.4  1.5  0.4  3.5
# 32  Donovan Mitchell  34.0  0.47  0.87  2.6  24.9   4.6  4.2  1.1  0.3  3.4
#
#     Cluster
# 6         2
# 8         2
# 23        2
# 29        2
# 32        2

# %%
DONCIC_SIMILAR = show_data_for_similar_players(
    cluster = 2,
    players = DONCIC.index.values
)

DONCIC_SIMILAR
# Out:
#                PLAYER   MPG   FG%   FT%  3PM   PTS  TREB   AST  STL  BLK   TO  \
# 0        James Harden  36.0  0.45  0.88  4.8  32.9   5.8   7.2  2.0  0.8  4.3
# 4       Kawhi Leonard  30.0  0.47  0.90  2.3  26.8   6.8   5.1  1.7  0.8  2.3
# 7   Russell Westbrook  36.0  0.50  0.79  0.7  30.7   8.7   6.5  2.0  0.4  4.4
# 11       LeBron James  34.0  0.51  0.71  2.6  26.2   7.5  10.6  1.1  0.6  4.7
# 19        Luka Doncic  32.0  0.44  0.77  2.3  27.4   9.2   8.6  1.1  0.3  3.7
#
#     Cluster
# 0         2
# 4         2
# 7         2
# 11        2
# 19        2

# %%
visualize_data_for_similar_players(
    player = DONCIC_SIMILAR,
    categories = ['FG%', 'FT%', '3PM', 'PTS', 'TREB', 'AST']
)

# %% [markdown]
# ## Athletic bigs

# %%
ab = nba.loc[nba['Cluster'] == 3]

ATHLETIC_BIGS = ab.set_index(['PLAYER'])

# %%
ab_recommender = create_recommender(ATHLETIC_BIGS)
ab_recommender.head()
# Out:
# PLAYER                 Anthony Davis  Nikola Jokic  John Collins  Joel Embiid  \
# PLAYER
# Anthony Davis               0.000000  6.926743e-03  1.393141e-03     0.003884
# Nikola Jokic                0.006927  1.110223e-16  9.864608e-03     0.006817
# John Collins                0.001393  9.864608e-03  2.220446e-16     0.003141
# Joel Embiid                 0.003884  6.817287e-03  3.140638e-03     0.000000
# Giannis Antetokounmpo       0.012546  1.484494e-02  1.441546e-02     0.008302
#
# PLAYER                 Giannis Antetokounmpo  Deandre Ayton  Ben Simmons  \
# PLAYER
# Anthony Davis                       0.012546       0.008790     0.023194
# Nikola Jokic                        0.014845       0.010397     0.008340
# John Collins                        0.014415       0.006770     0.027236
# Joel Embiid                         0.008302       0.004910     0.024383
# Giannis Antetokounmpo               0.000000       0.024463     0.044031
#
# PLAYER                 Christian Wood  Bam Adebayo  Domantas Sabonis  \
# PLAYER
# Anthony Davis                0.006615     0.029442          0.017142
# Nikola Jokic                 0.011635     0.018052          0.008290
# John Collins                 0.003540     0.029216          0.016201
# Joel Embiid                  0.005912     0.025511          0.011084
# Giannis Antetokounmpo        0.026570     0.055443          0.031712
#
# PLAYER                 Zion Williamson  Andre Drummond
# PLAYER
# Anthony Davis                 0.002894        0.018849
# Nikola Jokic                  0.012332        0.015748
# John Collins                  0.004094        0.016357
# Joel Embiid                   0.009817        0.010107
# Giannis Antetokounmpo         0.016189        0.032752

# %%
SIMMONS = top_similar_players_in_cluster(
    search='Ben Simmons',
    cluster_category=ab,
    recommender_df=ab_recommender,
    max_range=4
)

# %%
SIMMONS_SIMILAR = show_data_for_similar_players(
    cluster = 3,
    players = SIMMONS.index.values
)

# %%
visualize_data_for_similar_players(
    player = SIMMONS_SIMILAR,
    categories = ['FG%', 'FT%', '3PM', 'PTS', 'TREB', 'AST']
)

# %% [markdown]
# ## Shooters

# %%
sh = nba.loc[nba['Cluster'] == 5]

SHOOTERS = sh.set_index(['PLAYER'])

# %%
sh_recommender = create_recommender(SHOOTERS)
sh_recommender.head()
# Out:
# PLAYER           Jaren Jackson  Duncan Robinson    OG Anunoby  Rui Hachimura  \
# PLAYER
# Jaren Jackson     2.220446e-16         0.007673  1.380242e-02   5.621674e-03
# Duncan Robinson   7.672606e-03         0.000000  1.242521e-02   8.408752e-03
# OG Anunoby        1.380242e-02         0.012425  1.110223e-16   3.531280e-03
# Rui Hachimura     5.621674e-03         0.008409  3.531280e-03   1.110223e-16
# Naz Reid          2.668330e-03         0.015268  1.733929e-02   8.876506e-03
#
# PLAYER           Naz Reid  Lauri Markkanen  Danny Green  Danuel House  \
# PLAYER
# Jaren Jackson    0.002668         0.000996     0.017800      0.015133
# Duncan Robinson  0.015268         0.007112     0.010536      0.008265
# OG Anunoby       0.017339         0.011523     0.003272      0.001495
# Rui Hachimura    0.008877         0.004422     0.007485      0.005009
# Naz Reid         0.000000         0.002196     0.023987      0.021365
#
# PLAYER           Jordan Clarkson  Josh Hart  ...  Ish Smith  Delon Wright  \
# PLAYER                                       ...
# Jaren Jackson           0.006740   0.008260  ...   0.017088      0.019455
# Duncan Robinson         0.010655   0.012757  ...   0.010996      0.015231
# OG Anunoby              0.030249   0.004831  ...   0.011206      0.008499
# Rui Hachimura           0.014849   0.004358  ...   0.007692      0.008188
# Naz Reid                0.010721   0.006570  ...   0.021369      0.020921
#
# PLAYER           Trey Lyles  PJ Washington  Kevin Porter  Eric Gordon  \
# PLAYER
# Jaren Jackson      0.015704       0.007186      0.006764     0.008785
# Duncan Robinson    0.015397       0.010944      0.005876     0.001444
# OG Anunoby         0.001403       0.001961      0.003509     0.017029
# Rui Hachimura      0.005039       0.000795      0.000810     0.009656
# Naz Reid           0.016922       0.008838      0.010566     0.017821
#
# PLAYER           Ben McLemore  Troy Brown  Markieff Morris  Garrett Temple
# PLAYER
# Jaren Jackson        0.007577    0.014059         0.008218        0.016306
# Duncan Robinson      0.002212    0.014565         0.008660        0.007121
# OG Anunoby           0.016277    0.003850         0.001963        0.004396
# Rui Hachimura        0.010228    0.004366         0.002049        0.005706
# Naz Reid             0.013672    0.013535         0.009691        0.024521
#
# [5 rows x 42 columns]

# %%
DUNCAN = top_similar_players_in_cluster(
    search='Duncan Robinson',
    cluster_category=sh,
    recommender_df=sh_recommender,
    max_range=8
)

# %%
show_data_for_similar_players(
    cluster=5,
    players = DUNCAN.index.values
)
# Out:
#               PLAYER   MPG   FG%   FT%  3PM   PTS  TREB  AST  STL  BLK   TO  \
# 102  Duncan Robinson  28.0  0.47  0.88  3.9  14.0   3.3  1.5  0.5  0.2  0.9
# 155        JJ Redick  24.0  0.44  0.90  2.8  13.7   2.0  2.2  0.3  0.2  1.0
# 169      Tyler Herro  24.0  0.43  0.82  2.1  12.3   3.2  1.9  0.8  0.3  1.1
# 177       Seth Curry  25.0  0.48  0.86  2.1  11.8   2.4  1.3  0.7  0.3  1.1
# 179      Rodney Hood  28.0  0.44  0.87  1.3  12.7   2.3  2.0  0.9  0.2  0.9
# 181    Landry Shamet  26.0  0.45  0.81  2.9  12.1   2.0  1.8  0.6  0.1  0.7
# 193      Eric Gordon  27.0  0.41  0.82  2.9  14.2   2.0  1.7  0.5  0.4  1.1
# 194     Ben McLemore  20.0  0.45  0.87  2.6  10.6   2.3  1.0  0.6  0.3  0.9
#
#      Cluster
# 102        5
# 155        5
# 169        5
# 177        5
# 179        5
# 181        5
# 193        5
# 194        5

# %% [markdown]
# ## Guards

# %%
g = nba.loc[nba['Cluster'] == 7]

GUARDS = g.set_index(['PLAYER'])

# %%
g_recommender = create_recommender(GUARDS)
g_recommender.head()
# Out:
# PLAYER             Chris Paul  Brandon Ingram  Stephen Curry  Khris Middleton  \
# PLAYER
# Chris Paul       1.110223e-16        0.008561       0.007384         0.008085
# Brandon Ingram   8.561015e-03        0.000000       0.002453         0.000350
# Stephen Curry    7.384229e-03        0.002453       0.000000         0.003299
# Khris Middleton  8.084930e-03        0.000350       0.003299         0.000000
# Jamal Murray     4.930961e-03        0.002518       0.006038         0.002152
#
# PLAYER           Jamal Murray  Paul George  D'Angelo Russell  Fred VanVleet  \
# PLAYER
# Chris Paul           0.004931     0.013304          0.008343       0.005750
# Brandon Ingram       0.002518     0.002392          0.005276       0.015293
# Stephen Curry        0.006038     0.002591          0.001056       0.018129
# Khris Middleton      0.002152     0.002376          0.006654       0.013391
# Jamal Murray         0.000000     0.007461          0.007973       0.006123
#
# PLAYER           Kemba Walker  CJ McCollum  ...  Marcus Smart  Lou Williams  \
# PLAYER                                      ...
# Chris Paul           0.005513     0.007141  ...      0.010546      0.003036
# Brandon Ingram       0.001774     0.002145  ...      0.020061      0.004274
# Stephen Curry        0.002576     0.005765  ...      0.025840      0.004766
# Khris Middleton      0.001823     0.001981  ...      0.017203      0.004199
# Jamal Murray         0.001229     0.000429  ...      0.009470      0.001754
#
# PLAYER           Dennis Schroder  Bojan Bogdanovic  Evan Fournier  \
# PLAYER
# Chris Paul              0.004662          0.012879       0.009961
# Brandon Ingram          0.002157          0.004211       0.005836
# Stephen Curry           0.004182          0.009666       0.009674
# Khris Middleton         0.002103          0.003556       0.005445
# Jamal Murray            0.000519          0.002433       0.001926
#
# PLAYER           Spencer Dinwiddie  Devonte' Graham  Caris LeVert  \
# PLAYER
# Chris Paul                0.002581         0.003356      0.004503
# Brandon Ingram            0.006035         0.011126      0.003183
# Stephen Curry             0.006604         0.012060      0.007274
# Khris Middleton           0.006125         0.009997      0.002469
# Jamal Murray              0.001888         0.004393      0.000673
#
# PLAYER           Malcolm Brogdon  Terry Rozier
# PLAYER
# Chris Paul              0.003231      0.007103
# Brandon Ingram          0.015003      0.007544
# Stephen Curry           0.017211      0.012999
# Khris Middleton         0.013033      0.005703
# Jamal Murray            0.007282      0.002649
#
# [5 rows x 23 columns]

# %%
DEVONTE = top_similar_players_in_cluster(
    search="Devonte' Graham",
    cluster_category=g,
    recommender_df=g_recommender,
    max_range=4
)

CURRY = top_similar_players_in_cluster(
    search="Stephen Curry",
    cluster_category=g,
    recommender_df=g_recommender,
    max_range=4
)

# %%
show_data_for_similar_players(
    cluster=7,
    players = DEVONTE.index.values
)
# Out:
#                PLAYER   MPG   FG%   FT%  3PM   PTS  TREB  AST  STL  BLK   TO  \
# 43      Fred VanVleet  33.0  0.42  0.84  2.8  15.7   3.3  6.0  1.8  0.4  2.0
# 79  Spencer Dinwiddie  33.0  0.41  0.80  2.2  19.6   3.1  6.3  0.8  0.4  2.6
# 80    Devonte' Graham  33.0  0.39  0.81  3.3  17.3   3.3  6.6  1.0  0.2  2.7
# 89    Malcolm Brogdon  30.0  0.43  0.92  1.4  14.5   4.3  6.6  0.7  0.2  2.5
#
#     Cluster
# 43        7
# 79        7
# 80        7
# 89        7

# %%
show_data_for_similar_players(
    cluster=7,
    players = CURRY.index.values
)
# Out:
#               PLAYER   MPG   FG%   FT%  3PM   PTS  TREB  AST  STL  BLK   TO  \
# 22    Brandon Ingram  34.0  0.47  0.88  2.4  23.2   6.4  4.4  1.0  0.4  2.8
# 28     Stephen Curry  30.0  0.44  0.91  3.1  22.1   5.3  6.0  1.2  0.4  2.5
# 42  D'Angelo Russell  30.0  0.42  0.83  3.7  22.4   3.8  6.6  0.9  0.4  2.8
# 45      Kemba Walker  31.0  0.41  0.87  3.0  20.1   4.2  4.7  1.1  0.6  2.1
#
#     Cluster
# 22        7
# 28        7
# 42        7
# 45        7
